# %% [markdown]
# [![Open In SageMaker Studio Lab](https://studiolab.sagemaker.aws/studiolab.svg)](https://studiolab.sagemaker.aws/import/github/dkaratzas/DL2022-23/blob/main/Problems%208%20-%20RNNs/P8_RNNs.ipynb)

# %% [markdown]
# # Text generation with an RNN
#
# In this notebook we will learn how to generate text with a Recurrent Neural Network.
#
# We will work with a dataset of Shakespeare's writing from Andrej Karpathy's article [The Unreasonable Effectiveness of Recurrent Neural Networks](http://karpathy.github.io/2015/05/21/rnn-effectiveness/).
#
# Given a sequence of characters from this data (for example "Shakespear"), we will train a model to predict the next character in the sequence ("e"). Longer sequences of text can be generated by calling the model repeatedly.

# %% [markdown]
# ### Import the necessary modules

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
from torch.utils.data import TensorDataset, DataLoader

import matplotlib.pyplot as plt
from collections import Counter
import time
import os
import copy
print("PyTorch Version: ",torch.__version__)
# Out:
# PyTorch Version:  2.0.0+cu118

# %%
#If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

#  use gpu if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Using device:", device)
# Out:
# Using device: cuda

# %% [markdown]
# ### Download the Shakespeare dataset

# %%
! wget https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Out:
# --2023-05-01 09:37:40--  https://storage.googleapis.com/download.tensorflow.org/data/shakespeare.txt
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.74.128, 173.194.192.128, 209.85.145.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.74.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115394 (1.1M) [text/plain]
# Saving to: ‘shakespeare.txt.1’
#
# shakespeare.txt.1   100%[===================>]   1.06M  --.-KB/s    in 0.009s
#
# 2023-05-01 09:37:40 (120 MB/s) - ‘shakespeare.txt.1’ saved [1115394/1115394]

# %% [markdown]
# ###  Create a dataset class
#
# For training we need a dataset of (input, label) pairs. Where input and label are sequences of characters. At each time step the input is the current character and the label is the next character. For example:
#
# ```
# input = ['S', 'h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r']
# label = ['h', 'a', 'k', 'e', 's', 'p', 'e', 'a', 'r', 'e']
#  ```
#
# Actually we will vectorize the characters to convert them into numerical values.
#
# ```
# input = [44, 7, 0, 10, 4, 18, 15, 4, 0, 17]
# label = [7, 0, 10, 4, 18, 15, 4, 0, 17, 4]
# ```
#
# where each integer value is a class label, and the number of classes is the number of unique characters in our training data (our vocabulary size).

# %%
class DatasetFromTextFile():
    def __init__(self, filename, sequence_length):
        self.filename = filename
        self.sequence_length = sequence_length

        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = self.load_chars()
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        with open(self.filename) as fp:
            text = fp.read()
        print(f'Length of text: {len(text)} characters')
        return text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %% [markdown]
# Now we can use the [`torch.utils.data.TensorDataset`](https://pytorch.org/docs/stable/data.html) and [`torch.utils.data.Dataloader`](https://pytorch.org/docs/stable/data.html) classes to create the PyTorch dataloader. Notice that the `TensorDataset` class allows us to easily create a PyTorch `Dataset` from numpy arrays `(inputs, labels)`.

# %%
# Create the dataset
sequence_length = 100
ShakespeareDataset = DatasetFromTextFile('shakespeare.txt', sequence_length)

print(f'We have {ShakespeareDataset.x.shape[0]} input sequence samples of length {ShakespeareDataset.x.shape[1]} \
and {ShakespeareDataset.y.shape[0]} label sequences of length {ShakespeareDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader = DataLoader(ShakespeareDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Length of text: 1115394 characters
# Unique characters (vocabulary size): 65
# We have 11153 input sequence samples of length 100 and 11153 label sequences of length 100

# %% [markdown]
# ## Build the model
#
# Our model has three layers:
#
# * `torch.nn.Embedding`: The input layer. A trainable lookup table that will map each character-ID (class ID) to a dense vector with `embedding_dim` dimensions;
# * `torch.nn.GRU`: A type of RNN with `hidden_dim` units
# * `torch.nn.Linear`: The output layer, with number of outputs as our vocabulary size (`len(dataset.uniq_chars)`). It outputs one logit for each character in the vocabulary. These are the log-likelihood of each character according to the model.

# %% [markdown]
# For each character the model looks up the embedding, runs the GRU one timestep with the embedding as input, and applies the dense layer to generate logits predicting the log-likelihood of the next character:
#
# ![text_generation_training.png](data:image/png;base64,...)
#
# Image source: http://www.tensorflow.org

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 1:** Complete the code of the `Model` class. You need to embed your input using an `nn.Embedding` layer, create a GRU with `n_layers`, and then compute the output logits.
#
# </span>

# %%
class Model(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim,embedding_dim = embedding_dim)
        self.gru = nn.GRU(input_size = embedding_dim,num_layers = n_layers,hidden_size = hidden_dim,dropout = drop_prob, batch_first = True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.gru(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %% [markdown]
# Now we can instantiate the model as follows:

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model = Model(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model)
# Out:
# Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %% [markdown]
# ## Quick Experiment

# %% [markdown]
# Let's create a string and pass it through our model

# %%
data = torch.tensor([ShakespeareDataset.char_to_index[w] for w in "Hello"])
print(data.shape)
# Out:
# torch.Size([5])

# %% [markdown]
# Our model expects a batch. We will create a batch of 1, using this one data point we have created

# %%
data = data.unsqueeze(0) # this adds one more dimension (the batch one) to our data
print(data.shape)
# Out:
# torch.Size([1, 5])

# %% [markdown]
# Time to pass this through our model. To do so, we need to (1) move our data to the same device like the model and (2) initialise the state of our RNN

# %%
data = data.to(device)
state = model.init_hidden(batch_size = 1) # remember that we will use just a single data point here
state = state.to(device)
out, state = model(data, state) # The forward pass expects the current state as an argument, and returns the updated state in the output

print(out.shape)
# Out:
# torch.Size([1, 5, 65])

# %% [markdown]
# Our output returns 65 probability values for each character... We need to find which one is the maximum probability for each position, and convert it to the corresponding character

# %%
_, idxs = torch.max(out[0], dim = 1)

print([ShakespeareDataset.index_to_char[int(c)] for c in idxs])
# Out:
# ['O', '3', 'v', 'v', 'O']

# %% [markdown]
# As expected both inputs and outputs have the same shape, and the predicted characters are just random since the model is not trained yet.

# %% [markdown]
# ## Train the model
#
# Training a language model is essentially a classification problem. Given the previous RNN state, and the input character at this time step, predict the class of the next character.
#
# <span style="color:blue">
#
# **Exercise 2:** which loss function do you think we shall use to train our model?
#
# </span>

# %%
def train(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            state = model.init_hidden(batch_size) # Start with a new state in each batch
            state = state.to(device)

            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()

            y_pred, state = model(x, state)
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %% [markdown]
# Now train the model for 20 epochs and visualize the training loss curve.

# %%
num_epochs = 20

losses = train(train_loader, model, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.17770528793335}
# {'epoch': 0, 'batch': 30, 'loss': 2.2153971195220947}
# {'epoch': 0, 'batch': 60, 'loss': 1.9687751531600952}
# {'epoch': 0, 'batch': 90, 'loss': 1.8208881616592407}
# {'epoch': 0, 'batch': 120, 'loss': 1.6795161962509155}
# {'epoch': 0, 'batch': 150, 'loss': 1.5941585302352905}
# {'epoch': 1, 'batch': 0, 'loss': 1.569591999053955}
# {'epoch': 1, 'batch': 30, 'loss': 1.5246822834014893}
# {'epoch': 1, 'batch': 60, 'loss': 1.4546176195144653}
# {'epoch': 1, 'batch': 90, 'loss': 1.4959852695465088}
# {'epoch': 1, 'batch': 120, 'loss': 1.4705259799957275}
# {'epoch': 1, 'batch': 150, 'loss': 1.446784257888794}
# {'epoch': 2, 'batch': 0, 'loss': 1.3342820405960083}
# {'epoch': 2, 'batch': 30, 'loss': 1.3752355575561523}
# {'epoch': 2, 'batch': 60, 'loss': 1.3696855306625366}
# {'epoch': 2, 'batch': 90, 'loss': 1.3961100578308105}
# {'epoch': 2, 'batch': 120, 'loss': 1.3420836925506592}
# {'epoch': 2, 'batch': 150, 'loss': 1.3620164394378662}
# {'epoch': 3, 'batch': 0, 'loss': 1.2609976530075073}
# {'epoch': 3, 'batch': 30, 'loss': 1.2701963186264038}
# {'epoch': 3, 'batch': 60, 'loss': 1.3075652122497559}
# {'epoch': 3, 'batch': 90, 'loss': 1.3472282886505127}
# {'epoch': 3, 'batch': 120, 'loss': 1.2930983304977417}
# {'epoch': 3, 'batch': 150, 'loss': 1.3357200622558594}
# {'epoch': 4, 'batch': 0, 'loss': 1.261702060699463}
# {'epoch': 4, 'batch': 30, 'loss': 1.263970136642456}
# {'epoch': 4, 'batch': 60, 'loss': 1.2541285753250122}
# {'epoch': 4, 'batch': 90, 'loss': 1.2668548822402954}
# {'epoch': 4, 'batch': 120, 'loss': 1.2341763973236084}
# {'epoch': 4, 'batch': 150, 'loss': 1.256709098815918}
# {'epoch': 5, 'batch': 0, 'loss': 1.2276102304458618}
# {'epoch': 5, 'batch': 30, 'loss': 1.2316242456436157}
# {'epoch': 5, 'batch': 60, 'loss': 1.1897982358932495}
# {'epoch': 5, 'batch': 90, 'loss': 1.2024997472763062}
# {'epoch': 5, 'batch': 120, 'loss': 1.2278484106063843}
# {'epoch': 5, 'batch': 150, 'loss': 1.2156188488006592}
# {'epoch': 6, 'batch': 0, 'loss': 1.1582341194152832}
# {'epoch': 6, 'batch': 30, 'loss': 1.1439205408096313}
# {'epoch': 6, 'batch': 60, 'loss': 1.1369186639785767}
# {'epoch': 6, 'batch': 90, 'loss': 1.1710312366485596}
# {'epoch': 6, 'batch': 120, 'loss': 1.2025178670883179}
# {'epoch': 6, 'batch': 150, 'loss': 1.216503381729126}
# {'epoch': 7, 'batch': 0, 'loss': 1.1636207103729248}
# {'epoch': 7, 'batch': 30, 'loss': 1.1316543817520142}
# {'epoch': 7, 'batch': 60, 'loss': 1.1588975191116333}
# {'epoch': 7, 'batch': 90, 'loss': 1.1397095918655396}
# {'epoch': 7, 'batch': 120, 'loss': 1.1406984329223633}
# {'epoch': 7, 'batch': 150, 'loss': 1.2037479877471924}
# {'epoch': 8, 'batch': 0, 'loss': 1.1043753623962402}
# {'epoch': 8, 'batch': 30, 'loss': 1.0946037769317627}
# {'epoch': 8, 'batch': 60, 'loss': 1.12833571434021}
# {'epoch': 8, 'batch': 90, 'loss': 1.1251469850540161}
# {'epoch': 8, 'batch': 120, 'loss': 1.1133859157562256}
# {'epoch': 8, 'batch': 150, 'loss': 1.132478952407837}
# {'epoch': 9, 'batch': 0, 'loss': 1.0583950281143188}
# {'epoch': 9, 'batch': 30, 'loss': 1.0623276233673096}
# {'epoch': 9, 'batch': 60, 'loss': 1.0983000993728638}
# {'epoch': 9, 'batch': 90, 'loss': 1.080885410308838}
# {'epoch': 9, 'batch': 120, 'loss': 1.0974256992340088}
# {'epoch': 9, 'batch': 150, 'loss': 1.102384090423584}
# {'epoch': 10, 'batch': 0, 'loss': 1.0322765111923218}
# {'epoch': 10, 'batch': 30, 'loss': 1.0418903827667236}
# {'epoch': 10, 'batch': 60, 'loss': 1.0629574060440063}
# {'epoch': 10, 'batch': 90, 'loss': 1.0722224712371826}
# {'epoch': 10, 'batch': 120, 'loss': 1.0555154085159302}
# {'epoch': 10, 'batch': 150, 'loss': 1.0879379510879517}
# {'epoch': 11, 'batch': 0, 'loss': 0.98148512840271}
# {'epoch': 11, 'batch': 30, 'loss': 0.9941594004631042}
# {'epoch': 11, 'batch': 60, 'loss': 1.016063928604126}
# {'epoch': 11, 'batch': 90, 'loss': 1.0697554349899292}
# {'epoch': 11, 'batch': 120, 'loss': 1.049574851989746}
# {'epoch': 11, 'batch': 150, 'loss': 1.0460244417190552}
# {'epoch': 12, 'batch': 0, 'loss': 0.9550073742866516}
# {'epoch': 12, 'batch': 30, 'loss': 1.008658766746521}
# {'epoch': 12, 'batch': 60, 'loss': 0.9905669689178467}
# {'epoch': 12, 'batch': 90, 'loss': 1.0332351922988892}
# {'epoch': 12, 'batch': 120, 'loss': 1.0040688514709473}
# {'epoch': 12, 'batch': 150, 'loss': 1.030928134918213}
# {'epoch': 13, 'batch': 0, 'loss': 0.9341578483581543}
# {'epoch': 13, 'batch': 30, 'loss': 0.9329710602760315}
# {'epoch': 13, 'batch': 60, 'loss': 0.962788462638855}
# {'epoch': 13, 'batch': 90, 'loss': 0.9511372447013855}
# {'epoch': 13, 'batch': 120, 'loss': 0.9903112649917603}
# {'epoch': 13, 'batch': 150, 'loss': 0.9908379912376404}
# {'epoch': 14, 'batch': 0, 'loss': 0.9186611175537109}
# {'epoch': 14, 'batch': 30, 'loss': 0.9461073875427246}
# {'epoch': 14, 'batch': 60, 'loss': 0.9467713236808777}
# {'epoch': 14, 'batch': 90, 'loss': 0.9611597657203674}
# {'epoch': 14, 'batch': 120, 'loss': 0.9959859251976013}
# {'epoch': 14, 'batch': 150, 'loss': 0.9867603182792664}
# {'epoch': 15, 'batch': 0, 'loss': 0.8904234170913696}
# {'epoch': 15, 'batch': 30, 'loss': 0.908779501914978}
# {'epoch': 15, 'batch': 60, 'loss': 0.9112808108329773}
# {'epoch': 15, 'batch': 90, 'loss': 0.9466469287872314}
# {'epoch': 15, 'batch': 120, 'loss': 0.9483438730239868}
# {'epoch': 15, 'batch': 150, 'loss': 0.9718992114067078}
# {'epoch': 16, 'batch': 0, 'loss': 0.9028593301773071}
# {'epoch': 16, 'batch': 30, 'loss': 0.8834899067878723}
# {'epoch': 16, 'batch': 60, 'loss': 0.919477641582489}
# {'epoch': 16, 'batch': 90, 'loss': 0.9181744456291199}
# {'epoch': 16, 'batch': 120, 'loss': 0.942851722240448}
# {'epoch': 16, 'batch': 150, 'loss': 0.9413565993309021}
# {'epoch': 17, 'batch': 0, 'loss': 0.8643257021903992}
# {'epoch': 17, 'batch': 30, 'loss': 0.8694670796394348}
# {'epoch': 17, 'batch': 60, 'loss': 0.8825796246528625}
# {'epoch': 17, 'batch': 90, 'loss': 0.9247559309005737}
# {'epoch': 17, 'batch': 120, 'loss': 0.940141499042511}
# {'epoch': 17, 'batch': 150, 'loss': 0.9321141242980957}
# {'epoch': 18, 'batch': 0, 'loss': 0.8715863227844238}
# {'epoch': 18, 'batch': 30, 'loss': 0.8708245158195496}
# {'epoch': 18, 'batch': 60, 'loss': 0.8855118751525879}
# {'epoch': 18, 'batch': 90, 'loss': 0.8835022449493408}
# {'epoch': 18, 'batch': 120, 'loss': 0.8955023884773254}
# {'epoch': 18, 'batch': 150, 'loss': 0.9272885322570801}
# {'epoch': 19, 'batch': 0, 'loss': 0.8270573616027832}
# {'epoch': 19, 'batch': 30, 'loss': 0.8437524437904358}
# {'epoch': 19, 'batch': 60, 'loss': 0.8601603507995605}
# {'epoch': 19, 'batch': 90, 'loss': 0.8811122179031372}
# {'epoch': 19, 'batch': 120, 'loss': 0.8999884724617004}
# {'epoch': 19, 'batch': 150, 'loss': 0.9167672991752625}

# %%
# Visualize the loss evolution during training
plt.plot(losses)
plt.title('model loss')
plt.show()

# %% [markdown]
# ## Try the trained model
#
# Let's try again to predict some characters given the input sentence 'ROMEO:'. Now the predicted characters should be much better.

# %%
with torch.no_grad():
    input_str = 'ROMEO:'

    state = model.init_hidden(batch_size=1)
    state = state.to(device)
    data = torch.tensor([[ShakespeareDataset.char_to_index[char] for char in input_str]]).to(device)
    output, state = model(data, state)

    _, predicted_idxs = torch.max(output[0], dim = 1)
    predicted_idxs = predicted_idxs.cpu().numpy()

    predicted_str = ''.join([ShakespeareDataset.index_to_char[idx] for idx in predicted_idxs])

    print(f'Input shape: {data.size()}')
    print(f'Output shape: {data.size()}')
    print(f'Input string: {input_str}')
    print(f'Output string: {predicted_str}')
# Out:
# Input shape: torch.Size([1, 6])
# Output shape: torch.Size([1, 6])
# Input string: ROMEO:
# Output string: DMEO:

# %% [markdown]
# ## Generate new text

# %%
def predict(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]
    state = model.init_hidden(1)
    state = state.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):

        y_pred, state = model(x, state)

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

predicted = predict(ShakespeareDataset, model,'ROMEO:')
print(''.join(predicted))
# Out:
# ROMEO:
# Whitentless and most humble words to try;
# For this right will with more such safeguards thee from his
# As when for Edward's frosts and givest it there!
#
# QUEEN ELIZABETH:
# Padua be thus myself; I cannot go with quiet claim
# Our cousin's death, which you do love hence with hath yet nobler.
#
# KING EDWARD IV:
# Then give me looks, I would not go return.
#
# EXETER:
# Harry, the duky disposition cleanless
# Than thus.
#
# MIRANDA:
# O, no, sir! I am so for a feast;
# Livious and joyful builders, waving: for it is
# you fear it, for no mourning wooded in recessition
# To hopeless throne. Sent between us bosom,
# Fall becking impersant friar.
#
# PRINCE EDWARD:
# Nay, that is among that, my mother will not smooth
# As the parcies remove of bloody knightly faultly.
#
# MIRANDA:
# There's a great patrician: yet beheld I see
# thin in season. Was the foulest damned villain? we know
# 'Tis with the king exiled him to the proud with a sigh;
# And may perforce mayst thou wash the writing rest,
# And what we had too gentle thin away.
# Those men

# %% [markdown]
# While some of the sentences are grammatically correct, most do not make sense. The model has not learned the meaning of words (we would need a much larger corpus for that, and probably a word level language model), but consider the following:
#
# * The model is character-based. When training started, the model did not know how to spell an English word, or that words were even a unit of text. Now it does a pretty decent job on spelling.
#
# * The structure of the output resembles a play, blocks of text generally begin with a speaker name, in all capital letters similar to the dataset.
#
# * The model is trained on small batches of text (100 characters each), and is still able to generate a longer sequence of text with coherent structure.

# %% [markdown]
# # Homework
#
# <span style="color:blue">
#
# **Exercise 3:** Build two new models: one using Simple RNN cells (torch.nn.RNN) instead of GRUs(torch.nn.RNN), and the other using LSTMs (torch.nn.LSTM). Train all three models (GRU, LSTM, SimpleRNN) for 30 epochs and compare the loss curves. You can optionally try different configurations: embedding dimension, hidden layers dimensions, number of layers, etc.
#
# </span>

# %%
class Model(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(Model, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim,embedding_dim = embedding_dim)
        self.gru = nn.GRU(input_size = embedding_dim,num_layers = n_layers,hidden_size = hidden_dim,dropout = drop_prob, batch_first = True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.gru(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

model = Model(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(model)
# Out:
# Model(
#   (embedding): Embedding(65, 300)
#   (gru): GRU(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %%
num_epochs = 30

losses = train(train_loader, model, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.166955471038818}
# {'epoch': 0, 'batch': 30, 'loss': 2.2454683780670166}
# {'epoch': 0, 'batch': 60, 'loss': 1.9997349977493286}
# {'epoch': 0, 'batch': 90, 'loss': 1.7906550168991089}
# {'epoch': 0, 'batch': 120, 'loss': 1.6985331773757935}
# {'epoch': 0, 'batch': 150, 'loss': 1.6581528186798096}
# {'epoch': 1, 'batch': 0, 'loss': 1.5861245393753052}
# {'epoch': 1, 'batch': 30, 'loss': 1.546278476715088}
# {'epoch': 1, 'batch': 60, 'loss': 1.5254684686660767}
# {'epoch': 1, 'batch': 90, 'loss': 1.4918781518936157}
# {'epoch': 1, 'batch': 120, 'loss': 1.4220291376113892}
# {'epoch': 1, 'batch': 150, 'loss': 1.4579435586929321}
# {'epoch': 2, 'batch': 0, 'loss': 1.4160101413726807}
# {'epoch': 2, 'batch': 30, 'loss': 1.3866095542907715}
# {'epoch': 2, 'batch': 60, 'loss': 1.387518286705017}
# {'epoch': 2, 'batch': 90, 'loss': 1.3691356182098389}
# {'epoch': 2, 'batch': 120, 'loss': 1.3371423482894897}
# {'epoch': 2, 'batch': 150, 'loss': 1.3474177122116089}
# {'epoch': 3, 'batch': 0, 'loss': 1.3526051044464111}
# {'epoch': 3, 'batch': 30, 'loss': 1.31573486328125}
# {'epoch': 3, 'batch': 60, 'loss': 1.327034592628479}
# {'epoch': 3, 'batch': 90, 'loss': 1.3123478889465332}
# {'epoch': 3, 'batch': 120, 'loss': 1.2807008028030396}
# {'epoch': 3, 'batch': 150, 'loss': 1.3316656351089478}
# {'epoch': 4, 'batch': 0, 'loss': 1.2656505107879639}
# {'epoch': 4, 'batch': 30, 'loss': 1.224949598312378}
# {'epoch': 4, 'batch': 60, 'loss': 1.2487491369247437}
# {'epoch': 4, 'batch': 90, 'loss': 1.2425724267959595}
# {'epoch': 4, 'batch': 120, 'loss': 1.2524932622909546}
# {'epoch': 4, 'batch': 150, 'loss': 1.2446975708007812}
# {'epoch': 5, 'batch': 0, 'loss': 1.188663125038147}
# {'epoch': 5, 'batch': 30, 'loss': 1.2118408679962158}
# {'epoch': 5, 'batch': 60, 'loss': 1.2446002960205078}
# {'epoch': 5, 'batch': 90, 'loss': 1.2719966173171997}
# {'epoch': 5, 'batch': 120, 'loss': 1.1770994663238525}
# {'epoch': 5, 'batch': 150, 'loss': 1.2489936351776123}
# {'epoch': 6, 'batch': 0, 'loss': 1.144135594367981}
# {'epoch': 6, 'batch': 30, 'loss': 1.1983942985534668}
# {'epoch': 6, 'batch': 60, 'loss': 1.180526852607727}
# {'epoch': 6, 'batch': 90, 'loss': 1.1709191799163818}
# {'epoch': 6, 'batch': 120, 'loss': 1.175905704498291}
# {'epoch': 6, 'batch': 150, 'loss': 1.217209815979004}
# {'epoch': 7, 'batch': 0, 'loss': 1.1263666152954102}
# {'epoch': 7, 'batch': 30, 'loss': 1.0994762182235718}
# {'epoch': 7, 'batch': 60, 'loss': 1.1350679397583008}
# {'epoch': 7, 'batch': 90, 'loss': 1.1762715578079224}
# {'epoch': 7, 'batch': 120, 'loss': 1.1742794513702393}
# {'epoch': 7, 'batch': 150, 'loss': 1.1633622646331787}
# {'epoch': 8, 'batch': 0, 'loss': 1.1086586713790894}
# {'epoch': 8, 'batch': 30, 'loss': 1.1172454357147217}
# {'epoch': 8, 'batch': 60, 'loss': 1.1007792949676514}
# {'epoch': 8, 'batch': 90, 'loss': 1.1362452507019043}
# {'epoch': 8, 'batch': 120, 'loss': 1.1311020851135254}
# {'epoch': 8, 'batch': 150, 'loss': 1.1419408321380615}
# {'epoch': 9, 'batch': 0, 'loss': 1.0636987686157227}
# {'epoch': 9, 'batch': 30, 'loss': 1.0908198356628418}
# {'epoch': 9, 'batch': 60, 'loss': 1.0623774528503418}
# {'epoch': 9, 'batch': 90, 'loss': 1.1115992069244385}
# {'epoch': 9, 'batch': 120, 'loss': 1.1101727485656738}
# {'epoch': 9, 'batch': 150, 'loss': 1.1136776208877563}
# {'epoch': 10, 'batch': 0, 'loss': 1.02603280544281}
# {'epoch': 10, 'batch': 30, 'loss': 1.0286815166473389}
# {'epoch': 10, 'batch': 60, 'loss': 1.0655347108840942}
# {'epoch': 10, 'batch': 90, 'loss': 1.0333507061004639}
# {'epoch': 10, 'batch': 120, 'loss': 1.1027536392211914}
# {'epoch': 10, 'batch': 150, 'loss': 1.0557702779769897}
# {'epoch': 11, 'batch': 0, 'loss': 1.0168285369873047}
# {'epoch': 11, 'batch': 30, 'loss': 0.9938404560089111}
# {'epoch': 11, 'batch': 60, 'loss': 1.0158058404922485}
# {'epoch': 11, 'batch': 90, 'loss': 1.041664719581604}
# {'epoch': 11, 'batch': 120, 'loss': 1.0565085411071777}
# {'epoch': 11, 'batch': 150, 'loss': 1.0613843202590942}
# {'epoch': 12, 'batch': 0, 'loss': 0.9737629890441895}
# {'epoch': 12, 'batch': 30, 'loss': 0.9911324381828308}
# {'epoch': 12, 'batch': 60, 'loss': 1.0034382343292236}
# {'epoch': 12, 'batch': 90, 'loss': 1.003638505935669}
# {'epoch': 12, 'batch': 120, 'loss': 1.0248439311981201}
# {'epoch': 12, 'batch': 150, 'loss': 1.0558934211730957}
# {'epoch': 13, 'batch': 0, 'loss': 0.937699556350708}
# {'epoch': 13, 'batch': 30, 'loss': 0.948133111000061}
# {'epoch': 13, 'batch': 60, 'loss': 0.954181969165802}
# {'epoch': 13, 'batch': 90, 'loss': 1.005526065826416}
# {'epoch': 13, 'batch': 120, 'loss': 1.0027165412902832}
# {'epoch': 13, 'batch': 150, 'loss': 1.0169949531555176}
# {'epoch': 14, 'batch': 0, 'loss': 0.9347866773605347}
# {'epoch': 14, 'batch': 30, 'loss': 0.9341997504234314}
# {'epoch': 14, 'batch': 60, 'loss': 0.9499120116233826}
# {'epoch': 14, 'batch': 90, 'loss': 0.9481585025787354}
# {'epoch': 14, 'batch': 120, 'loss': 0.9827265739440918}
# {'epoch': 14, 'batch': 150, 'loss': 0.9808842539787292}
# {'epoch': 15, 'batch': 0, 'loss': 0.889922559261322}
# {'epoch': 15, 'batch': 30, 'loss': 0.9106292128562927}
# {'epoch': 15, 'batch': 60, 'loss': 0.8936116099357605}
# {'epoch': 15, 'batch': 90, 'loss': 0.9489353895187378}
# {'epoch': 15, 'batch': 120, 'loss': 0.9777058362960815}
# {'epoch': 15, 'batch': 150, 'loss': 0.9495767951011658}
# {'epoch': 16, 'batch': 0, 'loss': 0.8893285989761353}
# {'epoch': 16, 'batch': 30, 'loss': 0.871626615524292}
# {'epoch': 16, 'batch': 60, 'loss': 0.9041102528572083}
# {'epoch': 16, 'batch': 90, 'loss': 0.9235659241676331}
# {'epoch': 16, 'batch': 120, 'loss': 0.9480443000793457}
# {'epoch': 16, 'batch': 150, 'loss': 0.9512763023376465}
# {'epoch': 17, 'batch': 0, 'loss': 0.8600867390632629}
# {'epoch': 17, 'batch': 30, 'loss': 0.8634865283966064}
# {'epoch': 17, 'batch': 60, 'loss': 0.9033458232879639}
# {'epoch': 17, 'batch': 90, 'loss': 0.8838618397712708}
# {'epoch': 17, 'batch': 120, 'loss': 0.9475392699241638}
# {'epoch': 17, 'batch': 150, 'loss': 0.9450629353523254}
# {'epoch': 18, 'batch': 0, 'loss': 0.8502068519592285}
# {'epoch': 18, 'batch': 30, 'loss': 0.8698457479476929}
# {'epoch': 18, 'batch': 60, 'loss': 0.8672382831573486}
# {'epoch': 18, 'batch': 90, 'loss': 0.8954687714576721}
# {'epoch': 18, 'batch': 120, 'loss': 0.9255128502845764}
# {'epoch': 18, 'batch': 150, 'loss': 0.9229527115821838}
# {'epoch': 19, 'batch': 0, 'loss': 0.8197588324546814}
# {'epoch': 19, 'batch': 30, 'loss': 0.8781142234802246}
# {'epoch': 19, 'batch': 60, 'loss': 0.8504599928855896}
# {'epoch': 19, 'batch': 90, 'loss': 0.8748640418052673}
# {'epoch': 19, 'batch': 120, 'loss': 0.8985269069671631}
# {'epoch': 19, 'batch': 150, 'loss': 0.9380699992179871}
# {'epoch': 20, 'batch': 0, 'loss': 0.8401027917861938}
# {'epoch': 20, 'batch': 30, 'loss': 0.8353590369224548}
# {'epoch': 20, 'batch': 60, 'loss': 0.8220900893211365}
# {'epoch': 20, 'batch': 90, 'loss': 0.8626333475112915}
# {'epoch': 20, 'batch': 120, 'loss': 0.8614221811294556}
# {'epoch': 20, 'batch': 150, 'loss': 0.9097997546195984}
# {'epoch': 21, 'batch': 0, 'loss': 0.8284385204315186}
# {'epoch': 21, 'batch': 30, 'loss': 0.8123016357421875}
# {'epoch': 21, 'batch': 60, 'loss': 0.8463752865791321}
# {'epoch': 21, 'batch': 90, 'loss': 0.8818280696868896}
# {'epoch': 21, 'batch': 120, 'loss': 0.882047176361084}
# {'epoch': 21, 'batch': 150, 'loss': 0.8844029307365417}
# {'epoch': 22, 'batch': 0, 'loss': 0.8197827935218811}
# {'epoch': 22, 'batch': 30, 'loss': 0.816760241985321}
# {'epoch': 22, 'batch': 60, 'loss': 0.8303791284561157}
# {'epoch': 22, 'batch': 90, 'loss': 0.8637398481369019}
# {'epoch': 22, 'batch': 120, 'loss': 0.8722749352455139}
# {'epoch': 22, 'batch': 150, 'loss': 0.9150898456573486}
# {'epoch': 23, 'batch': 0, 'loss': 0.8126092553138733}
# {'epoch': 23, 'batch': 30, 'loss': 0.8125030398368835}
# {'epoch': 23, 'batch': 60, 'loss': 0.8695932030677795}
# {'epoch': 23, 'batch': 90, 'loss': 0.8395401835441589}
# {'epoch': 23, 'batch': 120, 'loss': 0.9096422791481018}
# {'epoch': 23, 'batch': 150, 'loss': 0.8912473320960999}
# {'epoch': 24, 'batch': 0, 'loss': 0.8317338824272156}
# {'epoch': 24, 'batch': 30, 'loss': 0.8284114003181458}
# {'epoch': 24, 'batch': 60, 'loss': 0.8365792632102966}
# {'epoch': 24, 'batch': 90, 'loss': 0.8759192824363708}
# {'epoch': 24, 'batch': 120, 'loss': 0.8706755638122559}
# {'epoch': 24, 'batch': 150, 'loss': 0.879351019859314}
# {'epoch': 25, 'batch': 0, 'loss': 0.8070108294487}
# {'epoch': 25, 'batch': 30, 'loss': 0.8343542218208313}
# {'epoch': 25, 'batch': 60, 'loss': 0.8639335036277771}
# {'epoch': 25, 'batch': 90, 'loss': 0.8776803612709045}
# {'epoch': 25, 'batch': 120, 'loss': 0.8813225030899048}
# {'epoch': 25, 'batch': 150, 'loss': 0.8892062902450562}
# {'epoch': 26, 'batch': 0, 'loss': 0.818865954875946}
# {'epoch': 26, 'batch': 30, 'loss': 0.8162338137626648}
# {'epoch': 26, 'batch': 60, 'loss': 0.844756543636322}
# {'epoch': 26, 'batch': 90, 'loss': 0.8481036424636841}
# {'epoch': 26, 'batch': 120, 'loss': 0.8806526064872742}
# {'epoch': 26, 'batch': 150, 'loss': 0.8767018914222717}
# {'epoch': 27, 'batch': 0, 'loss': 0.8364956378936768}
# {'epoch': 27, 'batch': 30, 'loss': 0.8050163984298706}
# {'epoch': 27, 'batch': 60, 'loss': 0.8500328660011292}
# {'epoch': 27, 'batch': 90, 'loss': 0.8663161396980286}
# {'epoch': 27, 'batch': 120, 'loss': 0.874563455581665}
# {'epoch': 27, 'batch': 150, 'loss': 0.8758350610733032}
# {'epoch': 28, 'batch': 0, 'loss': 0.8214681148529053}
# {'epoch': 28, 'batch': 30, 'loss': 0.8291492462158203}
# {'epoch': 28, 'batch': 60, 'loss': 0.857658326625824}
# {'epoch': 28, 'batch': 90, 'loss': 0.8752503991127014}
# {'epoch': 28, 'batch': 120, 'loss': 0.8392102122306824}
# {'epoch': 28, 'batch': 150, 'loss': 0.9021199941635132}
# {'epoch': 29, 'batch': 0, 'loss': 0.8031606078147888}
# {'epoch': 29, 'batch': 30, 'loss': 0.824716329574585}
# {'epoch': 29, 'batch': 60, 'loss': 0.8678858876228333}
# {'epoch': 29, 'batch': 90, 'loss': 0.8648375868797302}
# {'epoch': 29, 'batch': 120, 'loss': 0.8737289905548096}
# {'epoch': 29, 'batch': 150, 'loss': 0.8841425180435181}

# %%
# YOUR RESPONSE HERE
class SimpleRNN(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(SimpleRNN, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim,embedding_dim = embedding_dim)
        self.rnn = nn.RNN(input_size = embedding_dim,num_layers = n_layers,hidden_size = hidden_dim,dropout = drop_prob, batch_first = True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.rnn(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        hidden = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return hidden

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

modelRNN = SimpleRNN(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(modelRNN)
# Out:
# SimpleRNN(
#   (embedding): Embedding(65, 300)
#   (rnn): RNN(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %%
num_epochs = 30

lossesRNN = train(train_loader, modelRNN, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.164953708648682}
# {'epoch': 0, 'batch': 30, 'loss': 2.218878746032715}
# {'epoch': 0, 'batch': 60, 'loss': 1.9961864948272705}
# {'epoch': 0, 'batch': 90, 'loss': 1.8792310953140259}
# {'epoch': 0, 'batch': 120, 'loss': 1.8274325132369995}
# {'epoch': 0, 'batch': 150, 'loss': 1.7474654912948608}
# {'epoch': 1, 'batch': 0, 'loss': 1.6829663515090942}
# {'epoch': 1, 'batch': 30, 'loss': 1.5972477197647095}
# {'epoch': 1, 'batch': 60, 'loss': 1.6296603679656982}
# {'epoch': 1, 'batch': 90, 'loss': 1.577197551727295}
# {'epoch': 1, 'batch': 120, 'loss': 1.5686662197113037}
# {'epoch': 1, 'batch': 150, 'loss': 1.5607632398605347}
# {'epoch': 2, 'batch': 0, 'loss': 1.5337787866592407}
# {'epoch': 2, 'batch': 30, 'loss': 1.5205836296081543}
# {'epoch': 2, 'batch': 60, 'loss': 1.4940431118011475}
# {'epoch': 2, 'batch': 90, 'loss': 1.5248664617538452}
# {'epoch': 2, 'batch': 120, 'loss': 1.5231715440750122}
# {'epoch': 2, 'batch': 150, 'loss': 1.4653899669647217}
# {'epoch': 3, 'batch': 0, 'loss': 1.4479948282241821}
# {'epoch': 3, 'batch': 30, 'loss': 1.39923095703125}
# {'epoch': 3, 'batch': 60, 'loss': 1.4557032585144043}
# {'epoch': 3, 'batch': 90, 'loss': 1.4345600605010986}
# {'epoch': 3, 'batch': 120, 'loss': 1.420664668083191}
# {'epoch': 3, 'batch': 150, 'loss': 1.4563055038452148}
# {'epoch': 4, 'batch': 0, 'loss': 1.4217381477355957}
# {'epoch': 4, 'batch': 30, 'loss': 1.397464394569397}
# {'epoch': 4, 'batch': 60, 'loss': 1.4110287427902222}
# {'epoch': 4, 'batch': 90, 'loss': 1.3950822353363037}
# {'epoch': 4, 'batch': 120, 'loss': 1.4153541326522827}
# {'epoch': 4, 'batch': 150, 'loss': 1.3646876811981201}
# {'epoch': 5, 'batch': 0, 'loss': 1.3641246557235718}
# {'epoch': 5, 'batch': 30, 'loss': 1.3025054931640625}
# {'epoch': 5, 'batch': 60, 'loss': 1.3853381872177124}
# {'epoch': 5, 'batch': 90, 'loss': 1.379361629486084}
# {'epoch': 5, 'batch': 120, 'loss': 1.3764228820800781}
# {'epoch': 5, 'batch': 150, 'loss': 1.3448504209518433}
# {'epoch': 6, 'batch': 0, 'loss': 1.354067087173462}
# {'epoch': 6, 'batch': 30, 'loss': 1.3178249597549438}
# {'epoch': 6, 'batch': 60, 'loss': 1.3581348657608032}
# {'epoch': 6, 'batch': 90, 'loss': 1.3520143032073975}
# {'epoch': 6, 'batch': 120, 'loss': 1.3311303853988647}
# {'epoch': 6, 'batch': 150, 'loss': 1.3472820520401}
# {'epoch': 7, 'batch': 0, 'loss': 1.313960313796997}
# {'epoch': 7, 'batch': 30, 'loss': 1.3572367429733276}
# {'epoch': 7, 'batch': 60, 'loss': 1.3142722845077515}
# {'epoch': 7, 'batch': 90, 'loss': 1.340611219406128}
# {'epoch': 7, 'batch': 120, 'loss': 1.3404626846313477}
# {'epoch': 7, 'batch': 150, 'loss': 1.3378490209579468}
# {'epoch': 8, 'batch': 0, 'loss': 1.2736001014709473}
# {'epoch': 8, 'batch': 30, 'loss': 1.227527379989624}
# {'epoch': 8, 'batch': 60, 'loss': 1.332993984222412}
# {'epoch': 8, 'batch': 90, 'loss': 1.3311262130737305}
# {'epoch': 8, 'batch': 120, 'loss': 1.2859824895858765}
# {'epoch': 8, 'batch': 150, 'loss': 1.2471421957015991}
# {'epoch': 9, 'batch': 0, 'loss': 1.2273186445236206}
# {'epoch': 9, 'batch': 30, 'loss': 1.2842384576797485}
# {'epoch': 9, 'batch': 60, 'loss': 1.3123530149459839}
# {'epoch': 9, 'batch': 90, 'loss': 1.2686066627502441}
# {'epoch': 9, 'batch': 120, 'loss': 1.2951016426086426}
# {'epoch': 9, 'batch': 150, 'loss': 1.2877637147903442}
# {'epoch': 10, 'batch': 0, 'loss': 1.254825472831726}
# {'epoch': 10, 'batch': 30, 'loss': 1.257582426071167}
# {'epoch': 10, 'batch': 60, 'loss': 1.2954134941101074}
# {'epoch': 10, 'batch': 90, 'loss': 1.2534610033035278}
# {'epoch': 10, 'batch': 120, 'loss': 1.2863130569458008}
# {'epoch': 10, 'batch': 150, 'loss': 1.2650024890899658}
# {'epoch': 11, 'batch': 0, 'loss': 1.2020832300186157}
# {'epoch': 11, 'batch': 30, 'loss': 1.2348923683166504}
# {'epoch': 11, 'batch': 60, 'loss': 1.2424827814102173}
# {'epoch': 11, 'batch': 90, 'loss': 1.2495944499969482}
# {'epoch': 11, 'batch': 120, 'loss': 1.2835142612457275}
# {'epoch': 11, 'batch': 150, 'loss': 1.2721490859985352}
# {'epoch': 12, 'batch': 0, 'loss': 1.2299422025680542}
# {'epoch': 12, 'batch': 30, 'loss': 1.2440112829208374}
# {'epoch': 12, 'batch': 60, 'loss': 1.2247462272644043}
# {'epoch': 12, 'batch': 90, 'loss': 1.2440439462661743}
# {'epoch': 12, 'batch': 120, 'loss': 1.218183159828186}
# {'epoch': 12, 'batch': 150, 'loss': 1.2192786931991577}
# {'epoch': 13, 'batch': 0, 'loss': 1.2201722860336304}
# {'epoch': 13, 'batch': 30, 'loss': 1.2302312850952148}
# {'epoch': 13, 'batch': 60, 'loss': 1.237038016319275}
# {'epoch': 13, 'batch': 90, 'loss': 1.2610818147659302}
# {'epoch': 13, 'batch': 120, 'loss': 1.2458677291870117}
# {'epoch': 13, 'batch': 150, 'loss': 1.2509409189224243}
# {'epoch': 14, 'batch': 0, 'loss': 1.1732854843139648}
# {'epoch': 14, 'batch': 30, 'loss': 1.2171882390975952}
# {'epoch': 14, 'batch': 60, 'loss': 1.2112815380096436}
# {'epoch': 14, 'batch': 90, 'loss': 1.201444387435913}
# {'epoch': 14, 'batch': 120, 'loss': 1.2862566709518433}
# {'epoch': 14, 'batch': 150, 'loss': 1.2369035482406616}
# {'epoch': 15, 'batch': 0, 'loss': 1.2131381034851074}
# {'epoch': 15, 'batch': 30, 'loss': 1.1898739337921143}
# {'epoch': 15, 'batch': 60, 'loss': 1.210793375968933}
# {'epoch': 15, 'batch': 90, 'loss': 1.2091182470321655}
# {'epoch': 15, 'batch': 120, 'loss': 1.244584321975708}
# {'epoch': 15, 'batch': 150, 'loss': 1.2250685691833496}
# {'epoch': 16, 'batch': 0, 'loss': 1.180506706237793}
# {'epoch': 16, 'batch': 30, 'loss': 1.1991832256317139}
# {'epoch': 16, 'batch': 60, 'loss': 1.197085976600647}
# {'epoch': 16, 'batch': 90, 'loss': 1.2151259183883667}
# {'epoch': 16, 'batch': 120, 'loss': 1.1998209953308105}
# {'epoch': 16, 'batch': 150, 'loss': 1.203432559967041}
# {'epoch': 17, 'batch': 0, 'loss': 1.1375192403793335}
# {'epoch': 17, 'batch': 30, 'loss': 1.1755887269973755}
# {'epoch': 17, 'batch': 60, 'loss': 1.2047463655471802}
# {'epoch': 17, 'batch': 90, 'loss': 1.1758689880371094}
# {'epoch': 17, 'batch': 120, 'loss': 1.2330570220947266}
# {'epoch': 17, 'batch': 150, 'loss': 1.2270435094833374}
# {'epoch': 18, 'batch': 0, 'loss': 1.167944073677063}
# {'epoch': 18, 'batch': 30, 'loss': 1.230830192565918}
# {'epoch': 18, 'batch': 60, 'loss': 1.186058759689331}
# {'epoch': 18, 'batch': 90, 'loss': 1.1761553287506104}
# {'epoch': 18, 'batch': 120, 'loss': 1.1971244812011719}
# {'epoch': 18, 'batch': 150, 'loss': 1.1865826845169067}
# {'epoch': 19, 'batch': 0, 'loss': 1.1641732454299927}
# {'epoch': 19, 'batch': 30, 'loss': 1.1573669910430908}
# {'epoch': 19, 'batch': 60, 'loss': 1.183032512664795}
# {'epoch': 19, 'batch': 90, 'loss': 1.1798533201217651}
# {'epoch': 19, 'batch': 120, 'loss': 1.2171053886413574}
# {'epoch': 19, 'batch': 150, 'loss': 1.2132580280303955}
# {'epoch': 20, 'batch': 0, 'loss': 1.1563740968704224}
# {'epoch': 20, 'batch': 30, 'loss': 1.1457691192626953}
# {'epoch': 20, 'batch': 60, 'loss': 1.1503417491912842}
# {'epoch': 20, 'batch': 90, 'loss': 1.2053308486938477}
# {'epoch': 20, 'batch': 120, 'loss': 1.1776381731033325}
# {'epoch': 20, 'batch': 150, 'loss': 1.1878081560134888}
# {'epoch': 21, 'batch': 0, 'loss': 1.1503000259399414}
# {'epoch': 21, 'batch': 30, 'loss': 1.1409900188446045}
# {'epoch': 21, 'batch': 60, 'loss': 1.1595795154571533}
# {'epoch': 21, 'batch': 90, 'loss': 1.1696391105651855}
# {'epoch': 21, 'batch': 120, 'loss': 1.1875518560409546}
# {'epoch': 21, 'batch': 150, 'loss': 1.186591625213623}
# {'epoch': 22, 'batch': 0, 'loss': 1.1596977710723877}
# {'epoch': 22, 'batch': 30, 'loss': 1.1454405784606934}
# {'epoch': 22, 'batch': 60, 'loss': 1.1776947975158691}
# {'epoch': 22, 'batch': 90, 'loss': 1.1749773025512695}
# {'epoch': 22, 'batch': 120, 'loss': 1.1741851568222046}
# {'epoch': 22, 'batch': 150, 'loss': 1.1774979829788208}
# {'epoch': 23, 'batch': 0, 'loss': 1.1601790189743042}
# {'epoch': 23, 'batch': 30, 'loss': 1.1782805919647217}
# {'epoch': 23, 'batch': 60, 'loss': 1.1309162378311157}
# {'epoch': 23, 'batch': 90, 'loss': 1.154372215270996}
# {'epoch': 23, 'batch': 120, 'loss': 1.156416654586792}
# {'epoch': 23, 'batch': 150, 'loss': 1.1795272827148438}
# {'epoch': 24, 'batch': 0, 'loss': 1.1527351140975952}
# {'epoch': 24, 'batch': 30, 'loss': 1.1368017196655273}
# {'epoch': 24, 'batch': 60, 'loss': 1.1584820747375488}
# {'epoch': 24, 'batch': 90, 'loss': 1.146081566810608}
# {'epoch': 24, 'batch': 120, 'loss': 1.163263201713562}
# {'epoch': 24, 'batch': 150, 'loss': 1.1846230030059814}
# {'epoch': 25, 'batch': 0, 'loss': 1.1284056901931763}
# {'epoch': 25, 'batch': 30, 'loss': 1.1450060606002808}
# {'epoch': 25, 'batch': 60, 'loss': 1.1220077276229858}
# {'epoch': 25, 'batch': 90, 'loss': 1.17097806930542}
# {'epoch': 25, 'batch': 120, 'loss': 1.1708210706710815}
# {'epoch': 25, 'batch': 150, 'loss': 1.190609335899353}
# {'epoch': 26, 'batch': 0, 'loss': 1.1354278326034546}
# {'epoch': 26, 'batch': 30, 'loss': 1.1343234777450562}
# {'epoch': 26, 'batch': 60, 'loss': 1.147434115409851}
# {'epoch': 26, 'batch': 90, 'loss': 1.123847484588623}
# {'epoch': 26, 'batch': 120, 'loss': 1.1680188179016113}
# {'epoch': 26, 'batch': 150, 'loss': 1.18251371383667}
# {'epoch': 27, 'batch': 0, 'loss': 1.122110366821289}
# {'epoch': 27, 'batch': 30, 'loss': 1.1672251224517822}
# {'epoch': 27, 'batch': 60, 'loss': 1.1448997259140015}
# {'epoch': 27, 'batch': 90, 'loss': 1.1646591424942017}
# {'epoch': 27, 'batch': 120, 'loss': 1.1474108695983887}
# {'epoch': 27, 'batch': 150, 'loss': 1.1837568283081055}
# {'epoch': 28, 'batch': 0, 'loss': 1.141862392425537}
# {'epoch': 28, 'batch': 30, 'loss': 1.1033655405044556}
# {'epoch': 28, 'batch': 60, 'loss': 1.1602368354797363}
# {'epoch': 28, 'batch': 90, 'loss': 1.1554913520812988}
# {'epoch': 28, 'batch': 120, 'loss': 1.1608973741531372}
# {'epoch': 28, 'batch': 150, 'loss': 1.1614114046096802}
# {'epoch': 29, 'batch': 0, 'loss': 1.1209357976913452}
# {'epoch': 29, 'batch': 30, 'loss': 1.1508944034576416}
# {'epoch': 29, 'batch': 60, 'loss': 1.1282331943511963}
# {'epoch': 29, 'batch': 90, 'loss': 1.1459989547729492}
# {'epoch': 29, 'batch': 120, 'loss': 1.151382327079773}
# {'epoch': 29, 'batch': 150, 'loss': 1.1826685667037964}

# %%
plt.plot(lossesRNN)
plt.title('model loss')
plt.show()

# %%
class LSTM(nn.Module):
    def __init__(self, input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob=0.):
        super(LSTM, self).__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers

        # YOUR CODE HERE
        self.embedding = nn.Embedding(input_dim,embedding_dim = embedding_dim)
        self.lstm = nn.LSTM(input_size = embedding_dim,num_layers = n_layers,hidden_size = hidden_dim,dropout = drop_prob, batch_first = True)
        self.fc = nn.Linear(in_features = hidden_dim, out_features = output_dim)


    def forward(self, x, h):
        emb = self.embedding(x)
        out, h = self.lstm(emb, h)
        out = self.fc(out)
        return out, h

    def init_hidden(self, batch_size):
        " Initialize the hidden state of the RNN to zeros"
        #h_0 = torch.randn(self.num_directions * self.num_layers, self.batch_size, self.hidden_size)
        #c_0 = torch.randn(self.num_directions * self.num_layers, self.batch_size, self.hidden_size)
        #x, _ = self.BELT_LSTM(x, (h_0, c_0))
        h_0 = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        c_0 = nn.Parameter(torch.zeros(self.n_layers, batch_size, self.hidden_dim))
        return (h_0,c_0)

# %%
input_dim = len(ShakespeareDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(ShakespeareDataset.uniq_chars)
n_layers = 2
drop_prob = 0.2

modelLSTM = LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(modelLSTM)
# Out:
# LSTM(
#   (embedding): Embedding(65, 300)
#   (lstm): LSTM(300, 1024, num_layers=2, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=65, bias=True)
# )

# %%
def trainLSTM(dataloader, model, batch_size, sequence_length, num_epochs):
    model.train()

    criterion =  nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001)

    losses = []
    for epoch in range(num_epochs):

        for batch, (x, y) in enumerate(dataloader):
            state1,state2 = model.init_hidden(batch_size) # Start with a new state in each batch
            state1 = state1.to(device)
            state2 = state2.to(device)

            x = x.to(device)
            y = y.to(device)
            optimizer.zero_grad()

            y_pred, (state1,state2) = model(x, (state1,state2))
            loss = criterion(y_pred.transpose(1, 2), y)

            loss.backward()
            optimizer.step()

            if batch%30 == 0:
                print({ 'epoch': epoch, 'batch': batch, 'loss': loss.item() })
                losses.append(loss.item())
    return losses

# %%
def predictLSTM(dataset, model, text, next_chars=1000):
    model.eval()

    chars = [char for char in text]

    state1,state2 = model.init_hidden(1)
    state1 = state1.to(device)
    state2 = state2.to(device)

    # we start by feeding all the input characters to our model
    x = torch.tensor([dataset.char_to_index[char] for char in chars])
    x = x.unsqueeze(0) # create a batch of 1
    x = x.to(device)

    for i in range(0, next_chars):

        y_pred, (state1,state2) = model(x, (state1,state2))

        last_char_logits = y_pred[0][-1]
        p = torch.nn.functional.softmax(last_char_logits, dim=0).detach().cpu().numpy()
        char_index = np.random.choice(len(last_char_logits), p=p)
        chars.append(dataset.index_to_char[char_index])

        # the output of the model (a single character index) becomes the input at next iteration
        x = torch.tensor([[char_index]])
        x = x.to(device)

    return chars

# %%
num_epochs = 30

lossesLSTM = trainLSTM(train_loader, modelLSTM, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.171274662017822}
# {'epoch': 0, 'batch': 30, 'loss': 2.3051390647888184}
# {'epoch': 0, 'batch': 60, 'loss': 1.982683539390564}
# {'epoch': 0, 'batch': 90, 'loss': 1.8146579265594482}
# {'epoch': 0, 'batch': 120, 'loss': 1.7064714431762695}
# {'epoch': 0, 'batch': 150, 'loss': 1.6099913120269775}
# {'epoch': 1, 'batch': 0, 'loss': 1.5779335498809814}
# {'epoch': 1, 'batch': 30, 'loss': 1.517198085784912}
# {'epoch': 1, 'batch': 60, 'loss': 1.5076686143875122}
# {'epoch': 1, 'batch': 90, 'loss': 1.441648244857788}
# {'epoch': 1, 'batch': 120, 'loss': 1.509775996208191}
# {'epoch': 1, 'batch': 150, 'loss': 1.3907536268234253}
# {'epoch': 2, 'batch': 0, 'loss': 1.368766188621521}
# {'epoch': 2, 'batch': 30, 'loss': 1.3515396118164062}
# {'epoch': 2, 'batch': 60, 'loss': 1.3532594442367554}
# {'epoch': 2, 'batch': 90, 'loss': 1.3575198650360107}
# {'epoch': 2, 'batch': 120, 'loss': 1.3249162435531616}
# {'epoch': 2, 'batch': 150, 'loss': 1.3251501321792603}
# {'epoch': 3, 'batch': 0, 'loss': 1.2952041625976562}
# {'epoch': 3, 'batch': 30, 'loss': 1.2869956493377686}
# {'epoch': 3, 'batch': 60, 'loss': 1.298185110092163}
# {'epoch': 3, 'batch': 90, 'loss': 1.2983967065811157}
# {'epoch': 3, 'batch': 120, 'loss': 1.3306773900985718}
# {'epoch': 3, 'batch': 150, 'loss': 1.2842626571655273}
# {'epoch': 4, 'batch': 0, 'loss': 1.2408620119094849}
# {'epoch': 4, 'batch': 30, 'loss': 1.2060924768447876}
# {'epoch': 4, 'batch': 60, 'loss': 1.2111809253692627}
# {'epoch': 4, 'batch': 90, 'loss': 1.2520558834075928}
# {'epoch': 4, 'batch': 120, 'loss': 1.2501169443130493}
# {'epoch': 4, 'batch': 150, 'loss': 1.2190190553665161}
# {'epoch': 5, 'batch': 0, 'loss': 1.1901782751083374}
# {'epoch': 5, 'batch': 30, 'loss': 1.1742311716079712}
# {'epoch': 5, 'batch': 60, 'loss': 1.1485131978988647}
# {'epoch': 5, 'batch': 90, 'loss': 1.2082101106643677}
# {'epoch': 5, 'batch': 120, 'loss': 1.2170244455337524}
# {'epoch': 5, 'batch': 150, 'loss': 1.1467255353927612}
# {'epoch': 6, 'batch': 0, 'loss': 1.0996395349502563}
# {'epoch': 6, 'batch': 30, 'loss': 1.1300594806671143}
# {'epoch': 6, 'batch': 60, 'loss': 1.133643627166748}
# {'epoch': 6, 'batch': 90, 'loss': 1.1709394454956055}
# {'epoch': 6, 'batch': 120, 'loss': 1.13568913936615}
# {'epoch': 6, 'batch': 150, 'loss': 1.1735739707946777}
# {'epoch': 7, 'batch': 0, 'loss': 1.0844218730926514}
# {'epoch': 7, 'batch': 30, 'loss': 1.0735411643981934}
# {'epoch': 7, 'batch': 60, 'loss': 1.1002790927886963}
# {'epoch': 7, 'batch': 90, 'loss': 1.1382867097854614}
# {'epoch': 7, 'batch': 120, 'loss': 1.0962955951690674}
# {'epoch': 7, 'batch': 150, 'loss': 1.094815731048584}
# {'epoch': 8, 'batch': 0, 'loss': 1.0361297130584717}
# {'epoch': 8, 'batch': 30, 'loss': 1.0508369207382202}
# {'epoch': 8, 'batch': 60, 'loss': 1.0389515161514282}
# {'epoch': 8, 'batch': 90, 'loss': 1.0749163627624512}
# {'epoch': 8, 'batch': 120, 'loss': 1.1095737218856812}
# {'epoch': 8, 'batch': 150, 'loss': 1.116400957107544}
# {'epoch': 9, 'batch': 0, 'loss': 0.9945937395095825}
# {'epoch': 9, 'batch': 30, 'loss': 1.0173695087432861}
# {'epoch': 9, 'batch': 60, 'loss': 1.050856113433838}
# {'epoch': 9, 'batch': 90, 'loss': 1.0111066102981567}
# {'epoch': 9, 'batch': 120, 'loss': 1.0444748401641846}
# {'epoch': 9, 'batch': 150, 'loss': 1.041123390197754}
# {'epoch': 10, 'batch': 0, 'loss': 0.9422964453697205}
# {'epoch': 10, 'batch': 30, 'loss': 0.9697853326797485}
# {'epoch': 10, 'batch': 60, 'loss': 0.9601280093193054}
# {'epoch': 10, 'batch': 90, 'loss': 0.9725284576416016}
# {'epoch': 10, 'batch': 120, 'loss': 0.9992954730987549}
# {'epoch': 10, 'batch': 150, 'loss': 0.9960951805114746}
# {'epoch': 11, 'batch': 0, 'loss': 0.8893571496009827}
# {'epoch': 11, 'batch': 30, 'loss': 0.9130227565765381}
# {'epoch': 11, 'batch': 60, 'loss': 0.9028039574623108}
# {'epoch': 11, 'batch': 90, 'loss': 0.9558231830596924}
# {'epoch': 11, 'batch': 120, 'loss': 0.9594211578369141}
# {'epoch': 11, 'batch': 150, 'loss': 0.9581698775291443}
# {'epoch': 12, 'batch': 0, 'loss': 0.8805152177810669}
# {'epoch': 12, 'batch': 30, 'loss': 0.8492685556411743}
# {'epoch': 12, 'batch': 60, 'loss': 0.9003562331199646}
# {'epoch': 12, 'batch': 90, 'loss': 0.9106569886207581}
# {'epoch': 12, 'batch': 120, 'loss': 0.9280518889427185}
# {'epoch': 12, 'batch': 150, 'loss': 0.9531942009925842}
# {'epoch': 13, 'batch': 0, 'loss': 0.8149867057800293}
# {'epoch': 13, 'batch': 30, 'loss': 0.8188478946685791}
# {'epoch': 13, 'batch': 60, 'loss': 0.8316410183906555}
# {'epoch': 13, 'batch': 90, 'loss': 0.847016453742981}
# {'epoch': 13, 'batch': 120, 'loss': 0.8357570767402649}
# {'epoch': 13, 'batch': 150, 'loss': 0.8862675428390503}
# {'epoch': 14, 'batch': 0, 'loss': 0.7423863410949707}
# {'epoch': 14, 'batch': 30, 'loss': 0.7763428688049316}
# {'epoch': 14, 'batch': 60, 'loss': 0.7801579236984253}
# {'epoch': 14, 'batch': 90, 'loss': 0.7948689460754395}
# {'epoch': 14, 'batch': 120, 'loss': 0.8085122108459473}
# {'epoch': 14, 'batch': 150, 'loss': 0.8609050512313843}
# {'epoch': 15, 'batch': 0, 'loss': 0.7507106065750122}
# {'epoch': 15, 'batch': 30, 'loss': 0.7114050984382629}
# {'epoch': 15, 'batch': 60, 'loss': 0.7553130984306335}
# {'epoch': 15, 'batch': 90, 'loss': 0.7756723761558533}
# {'epoch': 15, 'batch': 120, 'loss': 0.7799736857414246}
# {'epoch': 15, 'batch': 150, 'loss': 0.7948845624923706}
# {'epoch': 16, 'batch': 0, 'loss': 0.6724987030029297}
# {'epoch': 16, 'batch': 30, 'loss': 0.7076881527900696}
# {'epoch': 16, 'batch': 60, 'loss': 0.7139851450920105}
# {'epoch': 16, 'batch': 90, 'loss': 0.7269018292427063}
# {'epoch': 16, 'batch': 120, 'loss': 0.7672471404075623}
# {'epoch': 16, 'batch': 150, 'loss': 0.7742143273353577}
# {'epoch': 17, 'batch': 0, 'loss': 0.6524785757064819}
# {'epoch': 17, 'batch': 30, 'loss': 0.655022382736206}
# {'epoch': 17, 'batch': 60, 'loss': 0.6706880927085876}
# {'epoch': 17, 'batch': 90, 'loss': 0.6836557984352112}
# {'epoch': 17, 'batch': 120, 'loss': 0.7088655233383179}
# {'epoch': 17, 'batch': 150, 'loss': 0.7254695892333984}
# {'epoch': 18, 'batch': 0, 'loss': 0.6174584031105042}
# {'epoch': 18, 'batch': 30, 'loss': 0.6386163830757141}
# {'epoch': 18, 'batch': 60, 'loss': 0.6349557638168335}
# {'epoch': 18, 'batch': 90, 'loss': 0.6469260454177856}
# {'epoch': 18, 'batch': 120, 'loss': 0.6686986684799194}
# {'epoch': 18, 'batch': 150, 'loss': 0.682518720626831}
# {'epoch': 19, 'batch': 0, 'loss': 0.5906705856323242}
# {'epoch': 19, 'batch': 30, 'loss': 0.5867239236831665}
# {'epoch': 19, 'batch': 60, 'loss': 0.6105122566223145}
# {'epoch': 19, 'batch': 90, 'loss': 0.6130497455596924}
# {'epoch': 19, 'batch': 120, 'loss': 0.6274447441101074}
# {'epoch': 19, 'batch': 150, 'loss': 0.6603503227233887}
# {'epoch': 20, 'batch': 0, 'loss': 0.5427035689353943}
# {'epoch': 20, 'batch': 30, 'loss': 0.5752670764923096}
# {'epoch': 20, 'batch': 60, 'loss': 0.5826273560523987}
# {'epoch': 20, 'batch': 90, 'loss': 0.5965301394462585}
# {'epoch': 20, 'batch': 120, 'loss': 0.6193385124206543}
# {'epoch': 20, 'batch': 150, 'loss': 0.6375099420547485}
# {'epoch': 21, 'batch': 0, 'loss': 0.524832546710968}
# {'epoch': 21, 'batch': 30, 'loss': 0.5441028475761414}
# {'epoch': 21, 'batch': 60, 'loss': 0.580461323261261}
# {'epoch': 21, 'batch': 90, 'loss': 0.5531519651412964}
# {'epoch': 21, 'batch': 120, 'loss': 0.5897826552391052}
# {'epoch': 21, 'batch': 150, 'loss': 0.600368857383728}
# {'epoch': 22, 'batch': 0, 'loss': 0.5221412181854248}
# {'epoch': 22, 'batch': 30, 'loss': 0.5075419545173645}
# {'epoch': 22, 'batch': 60, 'loss': 0.5361682176589966}
# {'epoch': 22, 'batch': 90, 'loss': 0.5574740767478943}
# {'epoch': 22, 'batch': 120, 'loss': 0.5679967403411865}
# {'epoch': 22, 'batch': 150, 'loss': 0.582124650478363}
# {'epoch': 23, 'batch': 0, 'loss': 0.49895015358924866}
# {'epoch': 23, 'batch': 30, 'loss': 0.48551997542381287}
# {'epoch': 23, 'batch': 60, 'loss': 0.5072519779205322}
# {'epoch': 23, 'batch': 90, 'loss': 0.5267686247825623}
# {'epoch': 23, 'batch': 120, 'loss': 0.5427870154380798}
# {'epoch': 23, 'batch': 150, 'loss': 0.5530496835708618}
# {'epoch': 24, 'batch': 0, 'loss': 0.4454250633716583}
# {'epoch': 24, 'batch': 30, 'loss': 0.4851280450820923}
# {'epoch': 24, 'batch': 60, 'loss': 0.4955243766307831}
# {'epoch': 24, 'batch': 90, 'loss': 0.5052409768104553}
# {'epoch': 24, 'batch': 120, 'loss': 0.5375358462333679}
# {'epoch': 24, 'batch': 150, 'loss': 0.5566138625144958}
# {'epoch': 25, 'batch': 0, 'loss': 0.4443071484565735}
# {'epoch': 25, 'batch': 30, 'loss': 0.466268390417099}
# {'epoch': 25, 'batch': 60, 'loss': 0.4736723005771637}
# {'epoch': 25, 'batch': 90, 'loss': 0.4937839210033417}
# {'epoch': 25, 'batch': 120, 'loss': 0.506695568561554}
# {'epoch': 25, 'batch': 150, 'loss': 0.5103371143341064}
# {'epoch': 26, 'batch': 0, 'loss': 0.42723721265792847}
# {'epoch': 26, 'batch': 30, 'loss': 0.42695313692092896}
# {'epoch': 26, 'batch': 60, 'loss': 0.4499475359916687}
# {'epoch': 26, 'batch': 90, 'loss': 0.45821624994277954}
# {'epoch': 26, 'batch': 120, 'loss': 0.5003470182418823}
# {'epoch': 26, 'batch': 150, 'loss': 0.5068451762199402}
# {'epoch': 27, 'batch': 0, 'loss': 0.40179261565208435}
# {'epoch': 27, 'batch': 30, 'loss': 0.44333377480506897}
# {'epoch': 27, 'batch': 60, 'loss': 0.44475051760673523}
# {'epoch': 27, 'batch': 90, 'loss': 0.46176475286483765}
# {'epoch': 27, 'batch': 120, 'loss': 0.4625338315963745}
# {'epoch': 27, 'batch': 150, 'loss': 0.49252384901046753}
# {'epoch': 28, 'batch': 0, 'loss': 0.409877747297287}
# {'epoch': 28, 'batch': 30, 'loss': 0.41213592886924744}
# {'epoch': 28, 'batch': 60, 'loss': 0.430620014667511}
# {'epoch': 28, 'batch': 90, 'loss': 0.4403742551803589}
# {'epoch': 28, 'batch': 120, 'loss': 0.4504145383834839}
# {'epoch': 28, 'batch': 150, 'loss': 0.49450722336769104}
# {'epoch': 29, 'batch': 0, 'loss': 0.39062947034835815}
# {'epoch': 29, 'batch': 30, 'loss': 0.39921629428863525}
# {'epoch': 29, 'batch': 60, 'loss': 0.4239632785320282}
# {'epoch': 29, 'batch': 90, 'loss': 0.43817150592803955}
# {'epoch': 29, 'batch': 120, 'loss': 0.4655475616455078}
# {'epoch': 29, 'batch': 150, 'loss': 0.4737566113471985}

# %%
plt.plot(lossesLSTM, label='LSTM')
plt.plot(losses, label='GRU')
plt.plot(lossesRNN, label='RNN')
plt.title('Model Loss')
plt.legend()
plt.show()

# %%
print("Results for the LSTM:")
predictedLSTM = predictLSTM(ShakespeareDataset, modelLSTM,'ROMEO:')
print(''.join(predictedLSTM))
print("----------------------------------------------------------------------------------------------")
# Out:
# Results for the LSTM:
# ROMEO:
# And I am lately king, command to him.
#
# YORK:
# Make an old woman, and he and I have done,
# For your own issue will have all this,
# Unless it be your title so much else
# Than done to her.
#
# LUCIO:
# How say you what?
#
# JULIET:
# Ay, mine own brother: I am safely you out.
#
# RUTES:
# Why, how now, Grous!
#
# CATESBY:
# No, my good lord; it is more than I will unto.
# O Warwick, Warwick! wert thou began to see his agon?
# Ay, my Lord Hastings, when he stamp'd, indeed!
#
# JOHN OF GAUNT:
# Alas, the Duke of Lancaster has been made,
# And give my just continually her sitting.
#
# ISABELLA:
# Can you content you, grave men, yet you are
# the friar that you have, which lever lives.
#
# KING RICHARD III:
# Why, what with saints being dispatch'd for it!
#
# MARIANA:
# Be ready, sir, show our friends! how their profession sounds?
# My title's heavy with a husband for his troop,
# And yet my suit is neck and strange.
# I am their mouths,
# That can my wanton stands in him. Yet you
# are amended to your country.
#
# BRUTUS:
# This stand's true judgment speak
# ----------------------------------------------------------------------------------------------

# %%
#Try the trained models
print("Results for the GRU:")
predicted = predict(ShakespeareDataset, model,'ROMEO:')
print(''.join(predicted))
print("----------------------------------------------------------------------------------------------")

print("Results for the RNN:")
predictedRNN = predict(ShakespeareDataset, modelRNN,'ROMEO:')
print(''.join(predictedRNN))
print("----------------------------------------------------------------------------------------------")

print("Results for the LSTM:")
predictedLSTM = predictLSTM(ShakespeareDataset, modelLSTM,'ROMEO:')
print(''.join(predictedLSTM))
print("----------------------------------------------------------------------------------------------")
# Out:
# Results for the GRU:
# ROMEO:
# Sying, fellow! why, not like an officer.
#
# PARIS:
# Is my sorrow was born, with words, which not the second hath charged
# With rapier and her prayers' soldiers; then surrently remain
# And speeds me dreams, cut off the heats of wife:
# Right swingly thanks, brave Gentleman, I pray, Pembler us,
# Or, if love call Edward fright that princely father's brothers so,
# Or else her pay have wrought his mind to prison,
# Now in pain that stops me mine. You're wrong his custom: if you
# can please you, sir, if you call do.
# It is too rather fleed.
#
# Second Citizen:
# Our honour free at good, which Warwick's rabement?
# Think you?
#
# Both:
# Your majesty of despite cold, hence; even from
# her eyes shall make him stripe: the first degree is Grunio; and
# Henry 'sight. Now, fellow, that victory is the noble;
# All under nothing slightly heavenly person,
# But though ever all my harms against Queen's spirit.
# But have for your faith, he'll make bold each pitied
# At a quart exElp the grief which I may;
# Subjous, that I see, that natu
# ----------------------------------------------------------------------------------------------
# Results for the RNN:
# ROMEO:
# It is, my lord.
#
# SAMPSON:
# Now, you mumble, not our hands begins to have hold my husband?
# What is it for the Tower.
# You know your swords by my servant,
# A malice owes laugh'd.
#
# KING EDWARD IV:
# Peace, enfiance must to bed-in dhen.
#
# ROMEO:
# Pray God, and speak of death,
# To pardon you, woe's sufferent report from hence?
# Says stant our tyranny by the world:
# If young Pleasons are sure to hear them
# then but one like suspicion
# As thus far fine sweets on eyes were they ne'er should seen
# Thy succession makes her;
# And so often play me on eaches.
#
# GRUMIO:
# First, with those sads, and made thee arms?
#
# ARIEL:
# At his devil.
#
# BENVOLIO:
# No, sir, to altou his part, and had blest to side
# To expresset of four happs of them here as it now.
#
# DUKE OF YORK:
#
# HASTINGS:
# And so he was my son, I'll utterance straid
# As I will not be your hair or grave
# As counterance, do this newly pleasant.
# Your wronged earth for beaten with tears o' kin.
#
# ROMEO:
# No doubt, my lord, I'll die them
# thee again deny more, as it some year
# ----------------------------------------------------------------------------------------------
# Results for the LSTM:
# ROMEO:
# I take the king and fearful deeds must stand:
# I smile at six and sullenst not at the farthest;
# Constable that my sons being call'd Alanco's:
# The rest, the heavens have all fight with thy birth;
# But my present assails the king can marry
# A thimble while: 'tis late confusions, peace,
# Provokes this against Coventry,
# And will, no doubt, us trust now to the death,
# On such a one as their cap in it; it had me,
# But one thing let me blame your mistress;
# Such as it is, being tender, raw against
# The manner and dissembling nature of these wars,
# Having no more but what they were to be desert,
# Whose most shall doing it, and eat and dream.
# O courteous Against the truth of What thou liest.
# Therefore, no dancing lives much little; alack,
# which knows not that he dares not for his purpose.
# Why, then, 'tis now no time to vein my country,
# And so did yet. We are bound to kill me.
#
# KATHARINA:
# Holy are yours! But mine own report.
#
# KING RICHARD III:
# Well, 'tis but not tongue to be drown'd in care,
# Her dowery w
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# We can see that the model with best performance is the LSTM one, because it have the lower loss value, and generate pretty large text with a good structure and real words. What wee can see is that much of the sentences make no sense

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# <span style="color:blue">
#
# **Exercise 4:** Train your best model on a different dataset. Use the 'inaugural' corpus of the [NLTK](https://www.nltk.org/) library. Once trained generate some text with as we did for the model trained on the Shakespeare dataset. Compare the generated texts with both models using the smae "seed" (input) text. What differences do you appreciate? Why are they different?
#
# </span>
#
# The Natural Language Toolkit, or more commonly NLTK, is a suite of datasets, libraries and models for symbolic and statistical natural language processing (NLP). The Inaugural Address Corpus contains the US presidential inaugural addresses from 1789 to 2017. The following code loads the 'inaugural' corpus:

# %%
import nltk
nltk.download('inaugural')

inaugural = nltk.corpus.inaugural
text = inaugural.raw()

print(f'Length of text: {len(text)} characters')
# Out:
# Length of text: 807276 characters
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Unzipping corpora/inaugural.zip.

# %%
class DatasetFromTextFile():
    def __init__(self, file1, sequence_length):
        self.file1 = file1
        self.sequence_length = sequence_length

        # The whole sequence of characters in the text file (including characters like the end of line character '\n', punctuation marks, etc.)
        self.chars = file1
        # The list of unique characters (our vocabulary)
        self.uniq_chars = self.get_uniq_chars()

        # A dictionary with indices as keys and characters as values
        self.index_to_char = {index: char for index, char in enumerate(self.uniq_chars)}
        # A dictionary with characters as keys and indices as values
        self.char_to_index = {char: index for index, char in enumerate(self.uniq_chars)}

        # The whole sequence of character indexes
        # We want to vectorize our text using one-hot vectors at character level
        # But instead of using the one-hot vector we just keep the index of the 1 value
        self.chars_indices = [self.char_to_index[w] for w in self.chars]

        # Split the sequence into chunks of `sequence_length` characters
        # `x` is the input to the model and `y` is the output of the model
        # `y` is the same seuqence as `x` but one character shifted to the right.
        self.x, self.y = self.get_data()

    def load_chars(self):
        with open(self.filename) as fp:
            text = fp.read()
        print(f'Length of text: {len(text)} characters')
        return text

    def get_uniq_chars(self):
        char_counts = Counter(self.chars)
        uniq_chars = sorted(char_counts, key=char_counts.get, reverse=True)
        print(f'Unique characters (vocabulary size): {len(uniq_chars)}')
        return uniq_chars

    def get_data(self):
        x,y = [], []
        for index in range(0, len(self.chars_indices)-self.sequence_length, self.sequence_length):
            x.append(np.array(self.chars_indices[index:index+self.sequence_length]))
            y.append(np.array(self.chars_indices[index+1:index+self.sequence_length+1]))

        return  torch.from_numpy(np.array(x)), torch.from_numpy(np.array(y)).long()

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        assert ((idx >= 0) & (idx < len(self.y))), "Dataset index out of range"
        return self.x[idx], self.y[idx]

# %%
# YOUR RESPONSE HERE
# Create the dataset
sequence_length = 100
InauguralDataset = DatasetFromTextFile(text, sequence_length)

print(f'We have {InauguralDataset.x.shape[0]} input sequence samples of length {InauguralDataset.x.shape[1]} \
and {InauguralDataset.y.shape[0]} label sequences of length {InauguralDataset.y.shape[1]}')

# Create the Torch DataLoader
batch_size = 64
train_loader_in = DataLoader(InauguralDataset, shuffle=True, batch_size=batch_size, drop_last=True)
# Out:
# Unique characters (vocabulary size): 85
# We have 8072 input sequence samples of length 100 and 8072 label sequences of length 100

# %%
input_dim = len(InauguralDataset.uniq_chars)
embedding_dim = 300
hidden_dim = 1024
output_dim = len(InauguralDataset.uniq_chars)
n_layers = 4
drop_prob = 0.2

InauguralLSTM = LSTM(input_dim, embedding_dim, hidden_dim, output_dim, n_layers, drop_prob).to(device)

print(InauguralLSTM)
# Out:
# LSTM(
#   (embedding): Embedding(85, 300)
#   (lstm): LSTM(300, 1024, num_layers=4, batch_first=True, dropout=0.2)
#   (fc): Linear(in_features=1024, out_features=85, bias=True)
# )

# %%
num_epochs = 30

lossesGRU = trainLSTM(train_loader_in, InauguralLSTM, batch_size, sequence_length, num_epochs)
# Out:
# {'epoch': 0, 'batch': 0, 'loss': 4.445428848266602}
# {'epoch': 0, 'batch': 30, 'loss': 2.979534387588501}
# {'epoch': 0, 'batch': 60, 'loss': 2.8585402965545654}
# {'epoch': 0, 'batch': 90, 'loss': 2.4757399559020996}
# {'epoch': 0, 'batch': 120, 'loss': 2.1114559173583984}
# {'epoch': 1, 'batch': 0, 'loss': 2.1135237216949463}
# {'epoch': 1, 'batch': 30, 'loss': 1.8491592407226562}
# {'epoch': 1, 'batch': 60, 'loss': 1.6659061908721924}
# {'epoch': 1, 'batch': 90, 'loss': 1.5731079578399658}
# {'epoch': 1, 'batch': 120, 'loss': 1.5065182447433472}
# {'epoch': 2, 'batch': 0, 'loss': 1.4519599676132202}
# {'epoch': 2, 'batch': 30, 'loss': 1.4145634174346924}
# {'epoch': 2, 'batch': 60, 'loss': 1.3496513366699219}
# {'epoch': 2, 'batch': 90, 'loss': 1.3221306800842285}
# {'epoch': 2, 'batch': 120, 'loss': 1.3216079473495483}
# {'epoch': 3, 'batch': 0, 'loss': 1.2951300144195557}
# {'epoch': 3, 'batch': 30, 'loss': 1.264535665512085}
# {'epoch': 3, 'batch': 60, 'loss': 1.2479608058929443}
# {'epoch': 3, 'batch': 90, 'loss': 1.1915326118469238}
# {'epoch': 3, 'batch': 120, 'loss': 1.2151367664337158}
# {'epoch': 4, 'batch': 0, 'loss': 1.1605082750320435}
# {'epoch': 4, 'batch': 30, 'loss': 1.1914267539978027}
# {'epoch': 4, 'batch': 60, 'loss': 1.2088195085525513}
# {'epoch': 4, 'batch': 90, 'loss': 1.1691697835922241}
# {'epoch': 4, 'batch': 120, 'loss': 1.1670979261398315}
# {'epoch': 5, 'batch': 0, 'loss': 1.1454790830612183}
# {'epoch': 5, 'batch': 30, 'loss': 1.1206648349761963}
# {'epoch': 5, 'batch': 60, 'loss': 1.1343071460723877}
# {'epoch': 5, 'batch': 90, 'loss': 1.0909476280212402}
# {'epoch': 5, 'batch': 120, 'loss': 1.1586863994598389}
# {'epoch': 6, 'batch': 0, 'loss': 1.0799245834350586}
# {'epoch': 6, 'batch': 30, 'loss': 1.0432770252227783}
# {'epoch': 6, 'batch': 60, 'loss': 1.0748387575149536}
# {'epoch': 6, 'batch': 90, 'loss': 1.068006992340088}
# {'epoch': 6, 'batch': 120, 'loss': 1.0965547561645508}
# {'epoch': 7, 'batch': 0, 'loss': 1.0609638690948486}
# {'epoch': 7, 'batch': 30, 'loss': 1.0664138793945312}
# {'epoch': 7, 'batch': 60, 'loss': 1.0894007682800293}
# {'epoch': 7, 'batch': 90, 'loss': 1.0697218179702759}
# {'epoch': 7, 'batch': 120, 'loss': 1.0269865989685059}
# {'epoch': 8, 'batch': 0, 'loss': 1.0360944271087646}
# {'epoch': 8, 'batch': 30, 'loss': 1.0210161209106445}
# {'epoch': 8, 'batch': 60, 'loss': 1.0155010223388672}
# {'epoch': 8, 'batch': 90, 'loss': 1.0366936922073364}
# {'epoch': 8, 'batch': 120, 'loss': 1.0676016807556152}
# {'epoch': 9, 'batch': 0, 'loss': 1.0163401365280151}
# {'epoch': 9, 'batch': 30, 'loss': 1.0367916822433472}
# {'epoch': 9, 'batch': 60, 'loss': 1.021501064300537}
# {'epoch': 9, 'batch': 90, 'loss': 1.0178858041763306}
# {'epoch': 9, 'batch': 120, 'loss': 1.006098985671997}
# {'epoch': 10, 'batch': 0, 'loss': 0.9795020818710327}
# {'epoch': 10, 'batch': 30, 'loss': 0.9702203273773193}
# {'epoch': 10, 'batch': 60, 'loss': 0.9839220643043518}
# {'epoch': 10, 'batch': 90, 'loss': 0.9995051622390747}
# {'epoch': 10, 'batch': 120, 'loss': 1.0370582342147827}
# {'epoch': 11, 'batch': 0, 'loss': 0.9729508757591248}
# {'epoch': 11, 'batch': 30, 'loss': 0.9235340356826782}
# {'epoch': 11, 'batch': 60, 'loss': 0.9726369380950928}
# {'epoch': 11, 'batch': 90, 'loss': 0.9692515730857849}
# {'epoch': 11, 'batch': 120, 'loss': 0.9761857390403748}
# {'epoch': 12, 'batch': 0, 'loss': 0.9294902086257935}
# {'epoch': 12, 'batch': 30, 'loss': 0.9263359308242798}
# {'epoch': 12, 'batch': 60, 'loss': 0.9319751262664795}
# {'epoch': 12, 'batch': 90, 'loss': 0.9503650069236755}
# {'epoch': 12, 'batch': 120, 'loss': 0.9492865204811096}
# {'epoch': 13, 'batch': 0, 'loss': 0.8866307139396667}
# {'epoch': 13, 'batch': 30, 'loss': 0.9181776642799377}
# {'epoch': 13, 'batch': 60, 'loss': 0.9209684729576111}
# {'epoch': 13, 'batch': 90, 'loss': 0.9373496770858765}
# {'epoch': 13, 'batch': 120, 'loss': 0.9536051154136658}
# {'epoch': 14, 'batch': 0, 'loss': 0.8774793148040771}
# {'epoch': 14, 'batch': 30, 'loss': 0.9009279012680054}
# {'epoch': 14, 'batch': 60, 'loss': 0.8994072675704956}
# {'epoch': 14, 'batch': 90, 'loss': 0.9016767144203186}
# {'epoch': 14, 'batch': 120, 'loss': 0.9319614171981812}
# {'epoch': 15, 'batch': 0, 'loss': 0.8484737277030945}
# {'epoch': 15, 'batch': 30, 'loss': 0.8711631298065186}
# {'epoch': 15, 'batch': 60, 'loss': 0.8599070906639099}
# {'epoch': 15, 'batch': 90, 'loss': 0.8997737765312195}
# {'epoch': 15, 'batch': 120, 'loss': 0.8727110028266907}
# {'epoch': 16, 'batch': 0, 'loss': 0.8170987963676453}
# {'epoch': 16, 'batch': 30, 'loss': 0.843532919883728}
# {'epoch': 16, 'batch': 60, 'loss': 0.8544297218322754}
# {'epoch': 16, 'batch': 90, 'loss': 0.8790863752365112}
# {'epoch': 16, 'batch': 120, 'loss': 0.8792514801025391}
# {'epoch': 17, 'batch': 0, 'loss': 0.8181244730949402}
# {'epoch': 17, 'batch': 30, 'loss': 0.8357753157615662}
# {'epoch': 17, 'batch': 60, 'loss': 0.8134351968765259}
# {'epoch': 17, 'batch': 90, 'loss': 0.8421872854232788}
# {'epoch': 17, 'batch': 120, 'loss': 0.8339889049530029}
# {'epoch': 18, 'batch': 0, 'loss': 0.7996025085449219}
# {'epoch': 18, 'batch': 30, 'loss': 0.7730247974395752}
# {'epoch': 18, 'batch': 60, 'loss': 0.7973315715789795}
# {'epoch': 18, 'batch': 90, 'loss': 0.8197978734970093}
# {'epoch': 18, 'batch': 120, 'loss': 0.8172812461853027}
# {'epoch': 19, 'batch': 0, 'loss': 0.7531374096870422}
# {'epoch': 19, 'batch': 30, 'loss': 0.752901017665863}
# {'epoch': 19, 'batch': 60, 'loss': 0.7893508672714233}
# {'epoch': 19, 'batch': 90, 'loss': 0.767223596572876}
# {'epoch': 19, 'batch': 120, 'loss': 0.7916384339332581}
# {'epoch': 20, 'batch': 0, 'loss': 0.7306237816810608}
# {'epoch': 20, 'batch': 30, 'loss': 0.7278185486793518}
# {'epoch': 20, 'batch': 60, 'loss': 0.7560455203056335}
# {'epoch': 20, 'batch': 90, 'loss': 0.765532374382019}
# {'epoch': 20, 'batch': 120, 'loss': 0.7962120771408081}
# {'epoch': 21, 'batch': 0, 'loss': 0.693449079990387}
# {'epoch': 21, 'batch': 30, 'loss': 0.7308840751647949}
# {'epoch': 21, 'batch': 60, 'loss': 0.7333260178565979}
# {'epoch': 21, 'batch': 90, 'loss': 0.7330270409584045}
# {'epoch': 21, 'batch': 120, 'loss': 0.7592003345489502}
# {'epoch': 22, 'batch': 0, 'loss': 0.6863601207733154}
# {'epoch': 22, 'batch': 30, 'loss': 0.7072901129722595}
# {'epoch': 22, 'batch': 60, 'loss': 0.7176604270935059}
# {'epoch': 22, 'batch': 90, 'loss': 0.7355275750160217}
# {'epoch': 22, 'batch': 120, 'loss': 0.743714451789856}
# {'epoch': 23, 'batch': 0, 'loss': 0.657106339931488}
# {'epoch': 23, 'batch': 30, 'loss': 0.6671289801597595}
# {'epoch': 23, 'batch': 60, 'loss': 0.7067693471908569}
# {'epoch': 23, 'batch': 90, 'loss': 0.7070119380950928}
# {'epoch': 23, 'batch': 120, 'loss': 0.6885753870010376}
# {'epoch': 24, 'batch': 0, 'loss': 0.6413132548332214}
# {'epoch': 24, 'batch': 30, 'loss': 0.6341636776924133}
# {'epoch': 24, 'batch': 60, 'loss': 0.6617605090141296}
# {'epoch': 24, 'batch': 90, 'loss': 0.6875720024108887}
# {'epoch': 24, 'batch': 120, 'loss': 0.6754475235939026}
# {'epoch': 25, 'batch': 0, 'loss': 0.6403024196624756}
# {'epoch': 25, 'batch': 30, 'loss': 0.6271155476570129}
# {'epoch': 25, 'batch': 60, 'loss': 0.6730278134346008}
# {'epoch': 25, 'batch': 90, 'loss': 0.6637439727783203}
# {'epoch': 25, 'batch': 120, 'loss': 0.6754289269447327}
# {'epoch': 26, 'batch': 0, 'loss': 0.6113715767860413}
# {'epoch': 26, 'batch': 30, 'loss': 0.617442786693573}
# {'epoch': 26, 'batch': 60, 'loss': 0.6410803198814392}
# {'epoch': 26, 'batch': 90, 'loss': 0.6499243974685669}
# {'epoch': 26, 'batch': 120, 'loss': 0.6482700109481812}
# {'epoch': 27, 'batch': 0, 'loss': 0.576941728591919}
# {'epoch': 27, 'batch': 30, 'loss': 0.606122612953186}
# {'epoch': 27, 'batch': 60, 'loss': 0.6037631034851074}
# {'epoch': 27, 'batch': 90, 'loss': 0.6218069195747375}
# {'epoch': 27, 'batch': 120, 'loss': 0.612708330154419}
# {'epoch': 28, 'batch': 0, 'loss': 0.574072539806366}
# {'epoch': 28, 'batch': 30, 'loss': 0.5751211643218994}
# {'epoch': 28, 'batch': 60, 'loss': 0.5828279256820679}
# {'epoch': 28, 'batch': 90, 'loss': 0.5966629981994629}
# {'epoch': 28, 'batch': 120, 'loss': 0.6231389045715332}
# {'epoch': 29, 'batch': 0, 'loss': 0.5496296882629395}
# {'epoch': 29, 'batch': 30, 'loss': 0.5652633905410767}
# {'epoch': 29, 'batch': 60, 'loss': 0.5642443299293518}
# {'epoch': 29, 'batch': 90, 'loss': 0.5898597836494446}
# {'epoch': 29, 'batch': 120, 'loss': 0.5867209434509277}

# %%
print("Results for the Inaugural GRU:")
predictedLSTM_in = predictLSTM(InauguralDataset, InauguralLSTM,'We need to reconstruct the country ')
print(''.join(predictedLSTM_in))
print("----------------------------------------------------------------------------------------------")
print("Results for the Romeo GRU:")
predictedLSTM_romeo = predictLSTM(ShakespeareDataset, modelLSTM,'We need to reconstruct the country ')
print(''.join(predictedLSTM_romeo))
print("----------------------------------------------------------------------------------------------")
# Out:
# Results for the Inaugural GRU:
# We need to reconstruct the country which they have trusted.
#
# In accordance with our institutions at the moment which has been the tranquillity of the cut of mankind.
#
# This was the surest new wholesome success that fairness. We did the tempest of liberty, to build the passions under which we pursue not only the cost of an object of constitutional right, to the public expenditures government had formed, in many States, in disposition to force accountability of political and political rights. The man who has been adopted by no participation, but more devoting their consequences essentially from the true proportions of some. But exclusively under the guardianship and guidance of the distinction for the cost of industry, for the support of duty which in the discharge of power in the Capital of this government. When are many in any act of Nouth is of important guidance. It was certainly unspeated by the people, under the unmost predictions of the American time.
#  For have seen the decisions of the event have been exefuted by t
# ----------------------------------------------------------------------------------------------
# Results for the Romeo GRU:
# We need to reconstruct the country wherein
# Remember of my vanity newly we,
# As will they last only sufficient to her:
# You do, as I love Henry's tells, God hath he them,
# Unhappy, when thy soul too late to me:
# Then, by my boy, that stands it all this:
# What have you figured from the firmal time?
#
# DUKE VINCENTIO:
# O, you hope so call'd a feverous train of men;
# Even that the effect of my revenges that you have,
# Which, only so much great misadvers' mood
# As Annatoric is but grieved for this.
#
# PRINCE EDWARD:
# Then, to be vough, you say the city hath
# Been born to live in Rome: but my sweet queen.
# O, use him for the reputation of my penitence;
# Worthy courtesy, she had not Grumio come by him;
# A mile when News for her bitter end,
# But to disprove this very hour. Come, sir, now.
#
# CORIOLANUS:
# Have you all mad, stay away by some offence?
#
# TYBALT:
# Follow me this from my lovely wish:
# Go, say I sent to him dishonour
# Than a deny can drive a town or two?
#
# BIANCA:
# Cambio is changed into Lucentio.
#
# LUCENTIO:
# Whate'er I bear the law than holy and
# ----------------------------------------------------------------------------------------------

# %% [markdown]
# We can clearly see that the model trained with the inagural dataset create a decent output with a well structured speech . Instead in the model trained with Shakespeare dataset despite we start with the same seed word, the model creates a theather structure text, because this model is trained with an script theater datset
